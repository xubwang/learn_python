# %%
import pandas as pd

# %%
bigmac = pd.read_csv("bigmac.csv", parse_dates=["Date"])
bigmac.head(3)
# Out:
# /var/folders/wx/608c2m1s0p30p78tw5zh92340000gp/T/ipykernel_23558/1134191104.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   bigmac = pd.read_csv("bigmac.csv", parse_dates=["Date"])
#         Date    Country  Price in US Dollars
# 0 2016-01-01  Argentina                 2.39
# 1 2016-01-01  Australia                 3.74
# 2 2016-01-01     Brazil                 3.35

# %%
bigmac.dtypes
# Out:
# Date                   datetime64[ns]
# Country                        object
# Price in US Dollars           float64
# dtype: object

# %%
bigmac.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 652 entries, 0 to 651
# Data columns (total 3 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Date                 652 non-null    datetime64[ns]
#  1   Country              652 non-null    object
#  2   Price in US Dollars  652 non-null    float64
# dtypes: datetime64[ns](1), float64(1), object(1)
# memory usage: 15.4+ KB

# %%
bigmac.set_index(keys=["Date", "Country"])
# Out:
#                           Price in US Dollars
# Date       Country
# 2016-01-01 Argentina                     2.39
#            Australia                     3.74
#            Brazil                        3.35
#            Britain                       4.22
#            Canada                        4.14
# ...                                       ...
# 2010-01-01 Turkey                        3.83
#            UAE                           2.99
#            Ukraine                       1.83
#            United States                 3.58
#            Uruguay                       3.32
#
# [652 rows x 1 columns]

# %%
bigmac.set_index(keys=["Country", "Date"])
# Out:
#                           Price in US Dollars
# Country       Date
# Argentina     2016-01-01                 2.39
# Australia     2016-01-01                 3.74
# Brazil        2016-01-01                 3.35
# Britain       2016-01-01                 4.22
# Canada        2016-01-01                 4.14
# ...                                       ...
# Turkey        2010-01-01                 3.83
# UAE           2010-01-01                 2.99
# Ukraine       2010-01-01                 1.83
# United States 2010-01-01                 3.58
# Uruguay       2010-01-01                 3.32
#
# [652 rows x 1 columns]

# %%
bigmac.nunique()
# Out:
# Date                    12
# Country                 58
# Price in US Dollars    330
# dtype: int64

# %%
bigmac.set_index(keys=["Date", "Country"], inplace=True)
bigmac.head(3)
# Out:
#                       Price in US Dollars
# Date       Country
# 2016-01-01 Argentina                 2.39
#            Australia                 3.74
#            Brazil                    3.35

# %%
bigmac.sort_index(inplace=True)
bigmac.head(3)
# Out:
#                       Price in US Dollars
# Date       Country
# 2010-01-01 Argentina                 1.84
#            Australia                 3.98
#            Brazil                    4.76

# %%
bigmac.index #a tuple of two values -> unique identifier of each row
# Out:
# MultiIndex([('2010-01-01',      'Argentina'),
#             ('2010-01-01',      'Australia'),
#             ('2010-01-01',         'Brazil'),
#             ('2010-01-01',        'Britain'),
#             ('2010-01-01',         'Canada'),
#             ('2010-01-01',          'Chile'),
#             ('2010-01-01',          'China'),
#             ('2010-01-01',       'Colombia'),
#             ('2010-01-01',     'Costa Rica'),
#             ('2010-01-01', 'Czech Republic'),
#             ...
#             ('2016-01-01',    'Switzerland'),
#             ('2016-01-01',         'Taiwan'),
#             ('2016-01-01',       'Thailand'),
#             ('2016-01-01',         'Turkey'),
#             ('2016-01-01',            'UAE'),
#             ('2016-01-01',        'Ukraine'),
#             ('2016-01-01',  'United States'),
#             ('2016-01-01',        'Uruguay'),
#             ('2016-01-01',      'Venezuela'),
#             ('2016-01-01',        'Vietnam')],
# ...

# %%
bigmac.index.names
# Out:
# FrozenList(['Date', 'Country'])

# %%
type(bigmac.index) #an index-type object
# Out:
# pandas.core.indexes.multi.MultiIndex

# %%
bigmac.index[0]
# Out:
# (Timestamp('2010-01-01 00:00:00'), 'Argentina')

# %%
type(bigmac.index[0])
# Out:
# tuple

# %% [markdown]
# ### get_level_values() - to get one specific level of index' values

# %%
bigmac = pd.read_csv("bigmac.csv", parse_dates=["Date"], index_col=["Date", "Country"])
bigmac.sort_index(inplace=True)
bigmac.head(3)
# Out:
# /var/folders/wx/608c2m1s0p30p78tw5zh92340000gp/T/ipykernel_23558/2603576825.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   bigmac = pd.read_csv("bigmac.csv", parse_dates=["Date"], index_col=["Date", "Country"])
#                       Price in US Dollars
# Date       Country
# 2010-01-01 Argentina                 1.84
#            Australia                 3.98
#            Brazil                    4.76

# %%
bigmac.index.get_level_values("Date")
bigmac.index.get_level_values(0)
# Out:
# DatetimeIndex(['2010-01-01', '2010-01-01', '2010-01-01', '2010-01-01',
#                '2010-01-01', '2010-01-01', '2010-01-01', '2010-01-01',
#                '2010-01-01', '2010-01-01',
#                ...
#                '2016-01-01', '2016-01-01', '2016-01-01', '2016-01-01',
#                '2016-01-01', '2016-01-01', '2016-01-01', '2016-01-01',
#                '2016-01-01', '2016-01-01'],
#               dtype='datetime64[ns]', name='Date', length=652, freq=None)

# %%
bigmac.index.get_level_values("Country")
bigmac.index.get_level_values(1)
# Out:
# Index(['Argentina', 'Australia', 'Brazil', 'Britain', 'Canada', 'Chile',
#        'China', 'Colombia', 'Costa Rica', 'Czech Republic',
#        ...
#        'Switzerland', 'Taiwan', 'Thailand', 'Turkey', 'UAE', 'Ukraine',
#        'United States', 'Uruguay', 'Venezuela', 'Vietnam'],
#       dtype='object', name='Country', length=652)

# %% [markdown]
# ### change index level name with set_names()

# %%
bigmac = pd.read_csv("bigmac.csv", parse_dates=["Date"], index_col=["Date", "Country"])
bigmac.sort_index(inplace=True)
bigmac.head(3)
# Out:
# /var/folders/wx/608c2m1s0p30p78tw5zh92340000gp/T/ipykernel_23558/2603576825.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   bigmac = pd.read_csv("bigmac.csv", parse_dates=["Date"], index_col=["Date", "Country"])
#                       Price in US Dollars
# Date       Country
# 2010-01-01 Argentina                 1.84
#            Australia                 3.98
#            Brazil                    4.76

# %%
bigmac.index.set_names(names=["Day", "Location"], inplace=True) #invoked on index object instead of the original dataframe

# %%
bigmac.head(3)
# Out:
#                       Price in US Dollars
# Day        Location
# 2010-01-01 Argentina                 1.84
#            Australia                 3.98
#            Brazil                    4.76

# %%
bigmac.index.set_names(names="Date", level=0)
bigmac.index.set_names(names="Date", level="Day", inplace=True)

# %%
bigmac.head(3)
# Out:
#                       Price in US Dollars
# Date       Location
# 2010-01-01 Argentina                 1.84
#            Australia                 3.98
#            Brazil                    4.76

# %% [markdown]
# ### sort_index() detailed on each level

# %%
bigmac = pd.read_csv("bigmac.csv", parse_dates=["Date"], index_col=["Date", "Country"])
# bigmac.sort_index(inplace=True)
bigmac.head(3)
# Out:
# /var/folders/wx/608c2m1s0p30p78tw5zh92340000gp/T/ipykernel_23558/3365870561.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   bigmac = pd.read_csv("bigmac.csv", parse_dates=["Date"], index_col=["Date", "Country"])
#                       Price in US Dollars
# Date       Country
# 2016-01-01 Argentina                 2.39
#            Australia                 3.74
#            Brazil                    3.35

# %%
bigmac.sort_index(ascending=True)
bigmac.sort_index(ascending=[False, True], inplace=True)

# %%
bigmac.head(5)
# Out:
#                       Price in US Dollars
# Date       Country
# 2016-01-01 Argentina                 2.39
#            Australia                 3.74
#            Austria                   3.76
#            Belgium                   4.25
#            Brazil                    3.35

# %%
#when the parameter of level is given, it's telling pandas to sort index just by this level
#also, passing either index position or index name is all right
bigmac.sort_index(level=0, ascending=True)
bigmac.sort_index(level="Date", ascending=True)
# Out:
#                           Price in US Dollars
# Date       Country
# 2010-01-01 Argentina                     1.84
#            Australia                     3.98
#            Brazil                        4.76
#            Britain                       3.67
#            Canada                        3.97
# ...                                       ...
# 2016-01-01 Ukraine                       1.54
#            United States                 4.93
#            Uruguay                       3.74
#            Venezuela                     0.66
#            Vietnam                       2.67
#
# [652 rows x 1 columns]

# %%
bigmac.head(3)
# Out:
#                       Price in US Dollars
# Date       Country
# 2016-01-01 Argentina                 2.39
#            Australia                 3.74
#            Austria                   3.76

# %%
bigmac.sort_index(level=1, ascending=True)
bigmac.sort_index(level="Country", ascending=True)
# Out:
#                       Price in US Dollars
# Date       Country
# 2010-01-01 Argentina                 1.84
# 2010-07-01 Argentina                 3.56
# 2011-07-01 Argentina                 4.84
# 2012-01-01 Argentina                 4.64
# 2012-07-01 Argentina                 4.16
# ...                                   ...
# 2014-01-01 Vietnam                   2.84
# 2014-07-01 Vietnam                   2.83
# 2015-01-01 Vietnam                   2.81
# 2015-07-01 Vietnam                   2.75
# 2016-01-01 Vietnam                   2.67
#
# [652 rows x 1 columns]

# %%
bigmac.head()
# Out:
#                       Price in US Dollars
# Date       Country
# 2016-01-01 Argentina                 2.39
#            Australia                 3.74
#            Austria                   3.76
#            Belgium                   4.25
#            Brazil                    3.35

# %%
bigmac = pd.read_csv("bigmac.csv", parse_dates=["Date"], index_col=["Date", "Country"])
# bigmac.sort_index(inplace=True)
bigmac.head()
# Out:
# /var/folders/wx/608c2m1s0p30p78tw5zh92340000gp/T/ipykernel_23558/3980429705.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   bigmac = pd.read_csv("bigmac.csv", parse_dates=["Date"], index_col=["Date", "Country"])
#                       Price in US Dollars
# Date       Country
# 2016-01-01 Argentina                 2.39
#            Australia                 3.74
#            Brazil                    3.35
#            Britain                   4.22
#            Canada                    4.14

# %%
bigmac.sort_index(level="Country", ascending=True, inplace=True)

# %%
bigmac.head() #-> turns out that "Date" level is also sorted in ascending order
# Out:
#                       Price in US Dollars
# Date       Country
# 2010-01-01 Argentina                 1.84
# 2010-07-01 Argentina                 3.56
# 2011-07-01 Argentina                 4.84
# 2012-01-01 Argentina                 4.64
# 2012-07-01 Argentina                 4.16

# %%
bigmac.loc["2010-01-01", "Argentina"]
bigmac.loc["2010-01-01", "Price in US Dollars"] #recommend to stick to this one
# Out:
# Country
# Argentina         1.84
# Australia         3.98
# Brazil            4.76
# Britain           3.67
# Canada            3.97
# Chile             3.18
# China             1.83
# Colombia          3.91
# Costa Rica        3.52
# Czech Republic    3.71
# Denmark           5.99
# Egypt             2.38
# Euro area         4.84
# Hong Kong         1.91
# Hungary           3.86
# Indonesia         2.24
# Israel            3.99
# Japan             3.50
# Latvia            3.09
# Lithuania         2.87
# Malaysia          2.08
# Mexico            2.50
# New Zealand       3.61
# Norway            7.02
# Pakistan          2.42
# Peru              2.81
# Philippines       2.21
# Poland            2.86
# Russia            2.34
# Saudi Arabia      2.67
# Singapore         3.19
# South Africa      2.46
# South Korea       2.98
# Sri Lanka         1.83
# Sweden            5.51
# Switzerland       6.30
# Taiwan            2.36
# Thailand          2.11
# Turkey            3.83
# ...

# %%
bigmac.loc[("2010-01-01", "Argentina"), "Price in US Dollars"] #a value
# Out:
# 1.84

# %%
bigmac.loc[("2010-01-01", "Argentina")] #Series
# Out:
# Price in US Dollars    1.84
# Name: (2010-01-01 00:00:00, Argentina), dtype: float64

# %%
bigmac.loc[("2010-01-01",)].head(3) #DataFrame
# Out:
# /var/folders/wx/608c2m1s0p30p78tw5zh92340000gp/T/ipykernel_23558/2129533363.py:1: PerformanceWarning: indexing past lexsort depth may impact performance.
#   bigmac.loc[("2010-01-01",)].head(3)
#            Price in US Dollars
# Country
# Argentina                 1.84
# Australia                 3.98
# Brazil                    4.76

# %%
# bigmac.loc[(slice(None), slice("Vietnam")), :]
bigmac.xs("Vietnam", level=1, drop_level=False) #yes "Date" level is indeed also sorted
# Out:
#                     Price in US Dollars
# Date       Country
# 2014-01-01 Vietnam                 2.84
# 2014-07-01 Vietnam                 2.83
# 2015-01-01 Vietnam                 2.81
# 2015-07-01 Vietnam                 2.75
# 2016-01-01 Vietnam                 2.67

# %%
bigmac = pd.read_csv("bigmac.csv", parse_dates=["Date"], index_col=["Date", "Country"])
bigmac.sort_index(inplace=True)
bigmac.head()
# Out:
# /var/folders/wx/608c2m1s0p30p78tw5zh92340000gp/T/ipykernel_23558/335020422.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   bigmac = pd.read_csv("bigmac.csv", parse_dates=["Date"], index_col=["Date", "Country"])
#                       Price in US Dollars
# Date       Country
# 2010-01-01 Argentina                 1.84
#            Australia                 3.98
#            Brazil                    4.76
#            Britain                   3.67
#            Canada                    3.97

# %%
#index position is not affected by the multiindex, it just counts from outside in for each row
bigmac.iloc[0]
# Out:
# Price in US Dollars    1.84
# Name: (2010-01-01 00:00:00, Argentina), dtype: float64

# %%
bigmac.iloc[[0,10,20,50,250]]
# Out:
#                       Price in US Dollars
# Date       Country
# 2010-01-01 Argentina                 1.84
#            Denmark                   5.99
#            Malaysia                  2.08
# 2010-07-01 Colombia                  4.39
# 2012-07-01 Turkey                    4.52

# %% [markdown]
# ### transpose()

# %%
bigmac = pd.read_csv("bigmac.csv", parse_dates=["Date"], index_col=["Date", "Country"])
bigmac.sort_index(inplace=True)
bigmac.head(3)
# Out:
# /var/folders/wx/608c2m1s0p30p78tw5zh92340000gp/T/ipykernel_23558/2603576825.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   bigmac = pd.read_csv("bigmac.csv", parse_dates=["Date"], index_col=["Date", "Country"])
#                       Price in US Dollars
# Date       Country
# 2010-01-01 Argentina                 1.84
#            Australia                 3.98
#            Brazil                    4.76

# %%
bigmac = bigmac.transpose() #method is not mutable
bigmac
# Out:
# Date                2010-01-01                                              \
# Country              Argentina Australia Brazil Britain Canada Chile China
# Price in US Dollars       1.84      3.98   4.76    3.67   3.97  3.18  1.83
#
# Date                                                    ...  2016-01-01  \
# Country             Colombia Costa Rica Czech Republic  ... Switzerland
# Price in US Dollars     3.91       3.52           3.71  ...        6.44
#
# Date                                                                    \
# Country             Taiwan Thailand Turkey   UAE Ukraine United States
# Price in US Dollars   2.08     3.09   3.41  3.54    1.54          4.93
#
# Date
# Country             Uruguay Venezuela Vietnam
# Price in US Dollars    3.74      0.66    2.67
#
# [1 rows x 652 columns]

# %%
bigmac.loc[("Price in US Dollars",), ('2010-01-01',         'Brazil'):('2010-01-01',          'China')]
# Out:
# Date                2010-01-01
# Country                 Brazil Britain Canada Chile China
# Price in US Dollars       4.76    3.67   3.97  3.18  1.83

# %%
bigmac.columns
# Out:
# MultiIndex([('2010-01-01',      'Argentina'),
#             ('2010-01-01',      'Australia'),
#             ('2010-01-01',         'Brazil'),
#             ('2010-01-01',        'Britain'),
#             ('2010-01-01',         'Canada'),
#             ('2010-01-01',          'Chile'),
#             ('2010-01-01',          'China'),
#             ('2010-01-01',       'Colombia'),
#             ('2010-01-01',     'Costa Rica'),
#             ('2010-01-01', 'Czech Republic'),
#             ...
#             ('2016-01-01',    'Switzerland'),
#             ('2016-01-01',         'Taiwan'),
#             ('2016-01-01',       'Thailand'),
#             ('2016-01-01',         'Turkey'),
#             ('2016-01-01',            'UAE'),
#             ('2016-01-01',        'Ukraine'),
#             ('2016-01-01',  'United States'),
#             ('2016-01-01',        'Uruguay'),
#             ('2016-01-01',      'Venezuela'),
#             ('2016-01-01',        'Vietnam')],
# ...

# %% [markdown]
# ### swaplevel()

# %%
bigmac = pd.read_csv("bigmac.csv", parse_dates=["Date"], index_col=["Date", "Country"])
bigmac.sort_index(inplace=True)
bigmac.head(3)
# Out:
# /var/folders/wx/608c2m1s0p30p78tw5zh92340000gp/T/ipykernel_23558/2603576825.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   bigmac = pd.read_csv("bigmac.csv", parse_dates=["Date"], index_col=["Date", "Country"])
#                       Price in US Dollars
# Date       Country
# 2010-01-01 Argentina                 1.84
#            Australia                 3.98
#            Brazil                    4.76

# %%
bigmac.swaplevel()
bigmac.swaplevel("Date", "Country")
bigmac.swaplevel("Country", "Date")
bigmac.swaplevel(0, 1)
bigmac.swaplevel(1, 0)
# Out:
#                           Price in US Dollars
# Country       Date
# Argentina     2010-01-01                 1.84
# Australia     2010-01-01                 3.98
# Brazil        2010-01-01                 4.76
# Britain       2010-01-01                 3.67
# Canada        2010-01-01                 3.97
# ...                                       ...
# Ukraine       2016-01-01                 1.54
# United States 2016-01-01                 4.93
# Uruguay       2016-01-01                 3.74
# Venezuela     2016-01-01                 0.66
# Vietnam       2016-01-01                 2.67
#
# [652 rows x 1 columns]

# %%
bigmac = bigmac.swaplevel(1, 0)

# %%
bigmac.head(3)
# Out:
#                       Price in US Dollars
# Country   Date
# Argentina 2010-01-01                 1.84
# Australia 2010-01-01                 3.98
# Brazil    2010-01-01                 4.76

# %% [markdown]
# ### stack(): from columns to index

# %%
world = pd.read_csv("worldstats.csv", index_col=["country", "year"])
world.head(3)
# Out:
#                   Population           GDP
# country    year
# Arab World 2015  392022276.0  2.530102e+12
#            2014  384222592.0  2.873600e+12
#            2013  376504253.0  2.846994e+12

# %%
world.stack()
# Out:
# country     year
# Arab World  2015  Population    3.920223e+08
#                   GDP           2.530102e+12
#             2014  Population    3.842226e+08
#                   GDP           2.873600e+12
#             2013  Population    3.765043e+08
#                                     ...
# Zimbabwe    1962  GDP           1.117602e+09
#             1961  Population    3.876638e+06
#                   GDP           1.096647e+09
#             1960  Population    3.752390e+06
#                   GDP           1.052990e+09
# Length: 22422, dtype: float64

# %%
type(world.stack())
# Out:
# pandas.core.series.Series

# %%
world.stack().to_frame()
# Out:
#                                        0
# country    year
# Arab World 2015 Population  3.920223e+08
#                 GDP         2.530102e+12
#            2014 Population  3.842226e+08
#                 GDP         2.873600e+12
#            2013 Population  3.765043e+08
# ...                                  ...
# Zimbabwe   1962 GDP         1.117602e+09
#            1961 Population  3.876638e+06
#                 GDP         1.096647e+09
#            1960 Population  3.752390e+06
#                 GDP         1.052990e+09
#
# [22422 rows x 1 columns]

# %% [markdown]
# ### unstack(): from index to columns

# %%
bigmac = pd.read_csv("bigmac.csv", parse_dates=["Date"], index_col=["Date", "Country"])
bigmac.sort_index(inplace=True)
bigmac.head(3)
# Out:
# /var/folders/wx/608c2m1s0p30p78tw5zh92340000gp/T/ipykernel_23558/2603576825.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   bigmac = pd.read_csv("bigmac.csv", parse_dates=["Date"], index_col=["Date", "Country"])
#                       Price in US Dollars
# Date       Country
# 2010-01-01 Argentina                 1.84
#            Australia                 3.98
#            Brazil                    4.76

# %%
s = world.stack()
s.head(3)
# Out:
# country     year
# Arab World  2015  Population    3.920223e+08
#                   GDP           2.530102e+12
#             2014  Population    3.842226e+08
# dtype: float64

# %%
s.unstack().head(3)
# Out:
#                   Population           GDP
# country     year
# Afghanistan 1960   8994793.0  5.377778e+08
#             1961   9164945.0  5.488889e+08
#             1962   9343772.0  5.466667e+08

# %%
s.unstack().unstack().head(3)
# Out:
#              Population                                                  \
# year               1960        1961        1962        1963        1964
# country
# Afghanistan   8994793.0   9164945.0   9343772.0   9531555.0   9728645.0
# Albania             NaN         NaN         NaN         NaN         NaN
# Algeria      11124892.0  11404859.0  11690152.0  11985130.0  12295973.0
#
#                                                                          ...  \
# year               1965        1966        1967        1968        1969  ...
# country                                                                  ...
# Afghanistan   9935358.0  10148841.0  10368600.0  10599790.0  10849510.0  ...
# Albania             NaN         NaN         NaN         NaN         NaN  ...
# Algeria      12626953.0  12980269.0  13354197.0  13744383.0  14144437.0  ...
#
#                       GDP                                            \
# ...

# %%
s.unstack().unstack().unstack().head()
# Out:
#             year  country
# Population  1960  Afghanistan     8994793.0
#                   Albania               NaN
#                   Algeria        11124892.0
#                   Andorra               NaN
#                   Angola                NaN
# dtype: float64

# %%
s.head(3)
# Out:
# country     year
# Arab World  2015  Population    3.920223e+08
#                   GDP           2.530102e+12
#             2014  Population    3.842226e+08
# dtype: float64

# %%
s.unstack(-1)
s.unstack(2)

s.unstack(-2)
s.unstack(1)
s.unstack("year")

s.unstack(-3)
s.unstack(0)
s.unstack("country").head(3)
# Out:
# country           Afghanistan  Albania       Algeria  Andorra  Angola  \
# year
# 1960 Population  8.994793e+06      NaN  1.112489e+07      NaN     NaN
#      GDP         5.377778e+08      NaN  2.723638e+09      NaN     NaN
# 1961 Population  9.164945e+06      NaN  1.140486e+07      NaN     NaN
#
# country          Antigua and Barbuda  Arab World  Argentina  Armenia  Aruba  \
# year
# 1960 Population                  NaN         NaN        NaN      NaN    NaN
#      GDP                         NaN         NaN        NaN      NaN    NaN
# 1961 Population                  NaN         NaN        NaN      NaN    NaN
#
# country          ...  Uzbekistan  Vanuatu  Venezuela, RB  Vietnam  \
# year             ...
# 1960 Population  ...         NaN      NaN   8.146845e+06      NaN
#      GDP         ...         NaN      NaN   8.607600e+09      NaN
# 1961 Population  ...         NaN      NaN   8.461684e+06      NaN
#
# ...

# %%
s.head(2)
# Out:
# country     year
# Arab World  2015  Population    3.920223e+08
#                   GDP           2.530102e+12
# dtype: float64

# %%
s.unstack(["year", "country"])
s.unstack([1,0])
# Out:
# year                2015          2014          2013          2012  \
# country       Arab World    Arab World    Arab World    Arab World
# Population  3.920223e+08  3.842226e+08  3.765043e+08  3.688026e+08
# GDP         2.530102e+12  2.873600e+12  2.846994e+12  2.773270e+12
#
# year                2011          2010          2009          2008  \
# country       Arab World    Arab World    Arab World    Arab World
# Population  3.610318e+08  3.531122e+08  3.450542e+08  3.368865e+08
# GDP         2.497945e+12  2.103825e+12  1.798878e+12  2.081343e+12
#
# year                2007          2006  ...          1969          1968  \
# country       Arab World    Arab World  ...      Zimbabwe      Zimbabwe
# Population  3.287666e+08  3.209067e+08  ...  5.036321e+06  4.874113e+06
# GDP         1.641666e+12  1.404190e+12  ...  1.747999e+09  1.479600e+09
#
# year                1967          1966          1965          1964  \
# ...

# %%
s.unstack(["country","year"])
s.unstack([0,1])
# Out:
# country       Arab World                                            \
# year                2015          2014          2013          2012
# Population  3.920223e+08  3.842226e+08  3.765043e+08  3.688026e+08
# GDP         2.530102e+12  2.873600e+12  2.846994e+12  2.773270e+12
#
# country                                                             \
# year                2011          2010          2009          2008
# Population  3.610318e+08  3.531122e+08  3.450542e+08  3.368865e+08
# GDP         2.497945e+12  2.103825e+12  1.798878e+12  2.081343e+12
#
# country                                 ...      Zimbabwe                \
# year                2007          2006  ...          1969          1968
# Population  3.287666e+08  3.209067e+08  ...  5.036321e+06  4.874113e+06
# GDP         1.641666e+12  1.404190e+12  ...  1.747999e+09  1.479600e+09
#
# country                                                             \
# ...

# %%
s.unstack(1, fill_value=0)
# s = s.unstack(1, fill_value=0)
# Out:
# year                            1960          1961          1962  \
# country
# Afghanistan Population  8.994793e+06  9.164945e+06  9.343772e+06
#             GDP         5.377778e+08  5.488889e+08  5.466667e+08
# Albania     Population  0.000000e+00  0.000000e+00  0.000000e+00
#             GDP         0.000000e+00  0.000000e+00  0.000000e+00
# Algeria     Population  1.112489e+07  1.140486e+07  1.169015e+07
# ...                              ...           ...           ...
# Yemen, Rep. GDP         0.000000e+00  0.000000e+00  0.000000e+00
# Zambia      Population  3.049586e+06  3.142848e+06  3.240664e+06
#             GDP         6.987397e+08  6.823597e+08  6.792797e+08
# Zimbabwe    Population  3.752390e+06  3.876638e+06  4.006262e+06
#             GDP         1.052990e+09  1.096647e+09  1.117602e+09
#
# year                            1963          1964          1965  \
# country
# Afghanistan Population  9.531555e+06  9.728645e+06  9.935358e+06
# ...

# %% [markdown]
# ### pivot()

# %%
sales = pd.read_csv("salesmen.csv", parse_dates=["Date"])
sales["Salesman"] = sales["Salesman"].astype("category")
sales.head(3)
# Out:
# /var/folders/wx/608c2m1s0p30p78tw5zh92340000gp/T/ipykernel_23558/449801316.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   sales = pd.read_csv("salesmen.csv", parse_dates=["Date"])
#         Date Salesman  Revenue
# 0 2016-01-01      Bob     7172
# 1 2016-01-02      Bob     6362
# 2 2016-01-03      Bob     5982

# %%
sales.nunique()
# Out:
# Date         366
# Salesman       5
# Revenue     1676
# dtype: int64

# %%
sales.pivot(index="Date", columns="Salesman", values="Revenue")
# Out:
# Salesman     Bob  Dave   Jeb  Oscar  Ronald
# Date
# 2016-01-01  7172  1864  4430   5250    2639
# 2016-01-02  6362  8278  8026   8661    4951
# 2016-01-03  5982  4226  5188   7075    2703
# 2016-01-04  7917  3868  3144   2524    4258
# 2016-01-05  7837  2287   938   2793    7771
# ...          ...   ...   ...    ...     ...
# 2016-12-27  2045  2843  6666    835    2981
# 2016-12-28   100  8888  1243   3073    6129
# 2016-12-29  4115  9490  3498   6424    7662
# 2016-12-30  2577  3594  8858   7088    2570
# 2016-12-31  3845  6830  9717   8408    2619
#
# [366 rows x 5 columns]

# %% [markdown]
# ### pivot_table()

# %%
foods = pd.read_csv("foods.csv")
foods.head(3)
# Out:
#   First Name  Gender      City Frequency     Item  Spend
# 0      Wanda  Female  Stamford    Weekly   Burger  15.66
# 1       Eric    Male  Stamford     Daily  Chalupa  10.56
# 2    Charles    Male  New York     Never    Sushi  42.14

# %%
foods.pivot_table(values="Spend", index="Gender", aggfunc="mean")
# Out:
#             Spend
# Gender
# Female  50.709629
# Male    49.397623

# %%
foods.pivot_table(values="Spend", index=["Gender", "Item"], aggfunc="sum")
# Out:
#                     Spend
# Gender Item
# Female Burger     4094.30
#        Burrito    4257.82
#        Chalupa    4152.26
#        Donut      4743.00
#        Ice Cream  4032.87
#        Sushi      4683.08
# Male   Burger     3671.43
#        Burrito    4012.62
#        Chalupa    3492.26
#        Donut      4015.76
#        Ice Cream  4854.12
#        Sushi      4059.85

# %%
foods.pivot_table(values="Spend", index=["Gender", "Item"], columns="City" ,aggfunc="sum")
# Out:
# City              New York  Philadelphia  Stamford
# Gender Item
# Female Burger      1239.04       1639.24   1216.02
#        Burrito      978.95       1458.76   1820.11
#        Chalupa      876.58       1673.33   1602.35
#        Donut       1446.78       1639.26   1656.96
#        Ice Cream   1521.62       1479.22   1032.03
#        Sushi       1480.29       1742.88   1459.91
# Male   Burger      1294.09        938.18   1439.16
#        Burrito     1399.40       1312.93   1300.29
#        Chalupa     1227.77       1114.23   1150.26
#        Donut       1345.27       1249.36   1421.13
#        Ice Cream   1603.63       2191.27   1059.22
#        Sushi       1396.15       1395.88   1267.82

# %%
foods.pivot_table(values="Spend", index=["Gender", "Item"], columns=["Frequency", "City"],aggfunc="sum")
# Out:
# Frequency           Daily                        Monthly               \
# City             New York Philadelphia Stamford New York Philadelphia
# Gender Item
# Female Burger      262.67       231.68   144.66   171.86       215.05
#        Burrito     224.45       321.57   195.63   122.74        34.28
#        Chalupa      43.19        23.49    95.70   158.37       289.96
#        Donut       478.10       247.40   124.35   284.53        50.25
#        Ice Cream   262.19       177.69    92.88    92.53        74.51
#        Sushi        81.07       348.53   393.27    93.16        78.71
# Male   Burger      319.46       112.70   197.72   187.29       213.14
#        Burrito     236.21       165.76   276.23   147.54        89.58
#        Chalupa      54.09       274.81   192.64   333.76        90.70
#        Donut       230.00       190.71   129.42   183.73       259.29
#        Ice Cream   178.22       148.69    15.17   152.20       386.55
# ...

# %%
#sum, mean, count, max, min

# %%
pd.pivot_table(data=foods,
              values="Spend", index=["Gender", "Item"], columns=["Frequency", "City"],aggfunc="sum")
# Out:
# Frequency           Daily                        Monthly               \
# City             New York Philadelphia Stamford New York Philadelphia
# Gender Item
# Female Burger      262.67       231.68   144.66   171.86       215.05
#        Burrito     224.45       321.57   195.63   122.74        34.28
#        Chalupa      43.19        23.49    95.70   158.37       289.96
#        Donut       478.10       247.40   124.35   284.53        50.25
#        Ice Cream   262.19       177.69    92.88    92.53        74.51
#        Sushi        81.07       348.53   393.27    93.16        78.71
# Male   Burger      319.46       112.70   197.72   187.29       213.14
#        Burrito     236.21       165.76   276.23   147.54        89.58
#        Chalupa      54.09       274.81   192.64   333.76        90.70
#        Donut       230.00       190.71   129.42   183.73       259.29
#        Ice Cream   178.22       148.69    15.17   152.20       386.55
# ...

# %% [markdown]
# ### pd.melt()

# %%
sales = pd.read_csv("quarters.csv")
sales
# Out:
#   Salesman      Q1      Q2      Q3      Q4
# 0    Boris  602908  233879  354479   32704
# 1      Bob   43790  514863  297151  544493
# 2    Tommy  392668  113579  430882  247231
# 3   Travis  834663  266785  749238  570524
# 4   Donald  580935  411379  110390  651572
# 5      Ted  656644   70803  375948  321388
# 6      Jeb  486141  600753  742716  404995
# 7    Stacy  479662  742806  770712    2501
# 8   Morgan  992673  879183   37945  293710

# %%
pd.melt(sales, id_vars="Salesman", var_name="Quarter", value_name="Revenue").head(10)
# Out:
#   Salesman Quarter  Revenue
# 0    Boris      Q1   602908
# 1      Bob      Q1    43790
# 2    Tommy      Q1   392668
# 3   Travis      Q1   834663
# 4   Donald      Q1   580935
# 5      Ted      Q1   656644
# 6      Jeb      Q1   486141
# 7    Stacy      Q1   479662
# 8   Morgan      Q1   992673
# 9    Boris      Q2   233879

# %%
sales.set_index("Salesman").stack().head(10)
# Out:
# Salesman
# Boris     Q1    602908
#           Q2    233879
#           Q3    354479
#           Q4     32704
# Bob       Q1     43790
#           Q2    514863
#           Q3    297151
#           Q4    544493
# Tommy     Q1    392668
#           Q2    113579
# dtype: int64
